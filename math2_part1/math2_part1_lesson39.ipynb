# %% [markdown]
# # Math 2, Part 1, Lesson 39

# %% [markdown]
# ## Using our tools (the `kids_math` package)

# %%
import kids_math as km

# %% [markdown]
# Let's get acquainted!  Type in your name in the empty string for the `my_name` variable below and give it to our program. Then execute your statement and the programs statement to receive a greeting!

# %% [markdown]
# _Your name in here '', like 'Dad'_

# %%
my_name = '' # your name in here '', like 'Dad'

# %% [markdown]
# _This is the program wanting your name_

# %%
km.say_hello(my_name)
# Out:
# Hello !

# %% [markdown]
# ## Try skip counting from 6s to 60

# %%
km.skip_counting(start_number=6, through_number=60, by_number=6)
# Out:
# 6
# 12
# 18
# 24
# 30
# 36
# 42
# 48
# 54
# 60

# %% [markdown]
# ## Greater than, less than

# %% [markdown]
# Is 85 less than, greater than, or equal to 122?
#
# Let's see how good we do using our program:
# ```python
# first_number = 85
# second_number = 122
#
# # pass our arguements into our function to find out if you guessed right!
# km.greater_than_less_than(first_number, second_number)
# ```

# %%
first_number = 85
second_number = 122

km.greater_than_less_than(first_number, second_number)
# Out:
# Is the first number greater than (>), less than (<), or equal to (=) the second number? [enter the symbol]<
# GREAT JOB!
# 0

# %%
from PIL import Image

# %%
im = Image.open('/Users/d3y010/Desktop/tenor.gif')

# %%
im
# Out:
# <PIL.GifImagePlugin.GifImageFile image mode=P size=498x297 at 0x113571390>

# %%
from IPython.display import HTML

# %%
HTML('<img src="/Users/d3y010/Desktop/tenor.gif">')
# Out:
# <img src="/Users/d3y010/Desktop/tenor.gif">

# %%
![]('https://media.giphy.com/media/3oD3YveOJWdwIAfZ5e/giphy.gif')
# Out:
# /bin/sh: -c: line 0: syntax error near unexpected token `'https://media.giphy.com/media/3oD3YveOJWdwIAfZ5e/giphy.gif''
# /bin/sh: -c: line 0: `[]('https://media.giphy.com/media/3oD3YveOJWdwIAfZ5e/giphy.gif')'

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
from IPython import display

from pathlib import Path
gifPath = Path("/Users/d3y010/Desktop/tenor.gif")
# Display GIF in Jupyter, CoLab, IPython
with open(gifPath,'rb') as f:
    display.Image(data=f.read(), format='png')
